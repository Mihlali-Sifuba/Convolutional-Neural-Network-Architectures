# %%
import numpy as np
from tensorflow.keras.utils import plot_model, set_random_seed, to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, BatchNormalization, Conv2D, MaxPool2D, AveragePooling2D, ZeroPadding2D, add, Flatten
from tensorflow.keras.datasets import mnist

# %%
# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
y_train.shape
# Out:
# (60000, 10)

# %%
# This ensures that the model is deterministic
set_random_seed(seed=6)

def Conv2D_BN(x, nb_filter, kernel_size, strides=(1, 1), padding='same'):
    x = Conv2D(nb_filter, kernel_size, padding=padding, strides=strides, activation='relu')(x)
    x = BatchNormalization(axis=3)(x)
    return x

def Residual_Block(inpt, nb_filter, kernel_size, strides=(1, 1), with_conv_shortcut=False):
    x = Conv2D_BN(inpt, nb_filter=nb_filter, kernel_size=kernel_size, strides=strides, padding='same')
    x = Conv2D_BN(x, nb_filter=nb_filter, kernel_size=kernel_size, padding='same')
    if with_conv_shortcut:
        shortcut = Conv2D_BN(inpt, nb_filter=nb_filter, strides=strides, kernel_size=kernel_size)
        x = add([x, shortcut])
        return x
    else:
        x = add([x, inpt])
        return x

# Model definition
inpt = Input(shape=(28, 28, 1))
x = ZeroPadding2D(padding=(3, 3), data_format='channels_last')(inpt)
x = Conv2D_BN(x, nb_filter=64, kernel_size=(7, 7), strides=(2, 2), padding='valid')
x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
# (56,56,64)
x = Residual_Block(x, nb_filter=64, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=64, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=64, kernel_size=(3, 3))
# (28,28,128)
x = Residual_Block(x, nb_filter=128, kernel_size=(3, 3), strides=(2, 2), with_conv_shortcut=True)
x = Residual_Block(x, nb_filter=128, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=128, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=128, kernel_size=(3, 3))
# (14,14,256)
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3), strides=(2, 2), with_conv_shortcut=True)
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=256, kernel_size=(3, 3))
# (7,7,512)
x = Residual_Block(x, nb_filter=512, kernel_size=(3, 3), strides=(2, 2), with_conv_shortcut=True)
x = Residual_Block(x, nb_filter=512, kernel_size=(3, 3))
x = Residual_Block(x, nb_filter=512, kernel_size=(3, 3))
# x = AveragePooling2D(pool_size=(7, 7))(x)
x = AveragePooling2D(pool_size=(1, 1))(x)
x = Flatten()(x)
x = Dense(units=10, activation='softmax')(x)

# Create a Keras Model
model = Model(inputs=inpt, outputs=x)
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x=x_train,
          y=y_train,
          validation_data=(x_test, y_test),
          epochs=20,
          batch_size=32)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=32,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  zero_padding2d_6 (ZeroPadding2  (None, 34, 34, 1)   0           ['input_7[0][0]']
#  D)
#
#  conv2d_216 (Conv2D)            (None, 14, 14, 64)   3200        ['zero_padding2d_6[0][0]']
#
#  batch_normalization_216 (Batch  (None, 14, 14, 64)  256         ['conv2d_216[0][0]']
#  Normalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 7, 7, 64)    0           ['batch_normalization_216[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 7, 7, 64)     36928       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_217 (Batch  (None, 7, 7, 64)    256         ['conv2d_217[0][0]']
#  Normalization)
#
#  conv2d_218 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_217[0][0]']
#
#  batch_normalization_218 (Batch  (None, 7, 7, 64)    256         ['conv2d_218[0][0]']
#  Normalization)
#
#  add_96 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_218[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 7, 7, 64)     36928       ['add_96[0][0]']
#
#  batch_normalization_219 (Batch  (None, 7, 7, 64)    256         ['conv2d_219[0][0]']
#  Normalization)
#
#  conv2d_220 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_219[0][0]']
#
#  batch_normalization_220 (Batch  (None, 7, 7, 64)    256         ['conv2d_220[0][0]']
#  Normalization)
#
#  add_97 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_220[0][0]',
#                                                                   'add_96[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 7, 7, 64)     36928       ['add_97[0][0]']
#
#  batch_normalization_221 (Batch  (None, 7, 7, 64)    256         ['conv2d_221[0][0]']
#  Normalization)
#
#  conv2d_222 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_221[0][0]']
#
#  batch_normalization_222 (Batch  (None, 7, 7, 64)    256         ['conv2d_222[0][0]']
#  Normalization)
#
#  add_98 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_222[0][0]',
#                                                                   'add_97[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 4, 4, 128)    73856       ['add_98[0][0]']
#
#  batch_normalization_223 (Batch  (None, 4, 4, 128)   512         ['conv2d_223[0][0]']
#  Normalization)
#
#  conv2d_224 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_223[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 4, 4, 128)    73856       ['add_98[0][0]']
#
#  batch_normalization_224 (Batch  (None, 4, 4, 128)   512         ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 4, 4, 128)   512         ['conv2d_225[0][0]']
#  Normalization)
#
#  add_99 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_224[0][0]',
#                                                                   'batch_normalization_225[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 4, 4, 128)    147584      ['add_99[0][0]']
#
#  batch_normalization_226 (Batch  (None, 4, 4, 128)   512         ['conv2d_226[0][0]']
#  Normalization)
#
#  conv2d_227 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_226[0][0]']
#
#  batch_normalization_227 (Batch  (None, 4, 4, 128)   512         ['conv2d_227[0][0]']
#  Normalization)
#
#  add_100 (Add)                  (None, 4, 4, 128)    0           ['batch_normalization_227[0][0]',
#                                                                   'add_99[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 4, 4, 128)    147584      ['add_100[0][0]']
#
#  batch_normalization_228 (Batch  (None, 4, 4, 128)   512         ['conv2d_228[0][0]']
#  Normalization)
#
#  conv2d_229 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_228[0][0]']
#
#  batch_normalization_229 (Batch  (None, 4, 4, 128)   512         ['conv2d_229[0][0]']
#  Normalization)
#
#  add_101 (Add)                  (None, 4, 4, 128)    0           ['batch_normalization_229[0][0]',
#                                                                   'add_100[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 4, 4, 128)    147584      ['add_101[0][0]']
#
#  batch_normalization_230 (Batch  (None, 4, 4, 128)   512         ['conv2d_230[0][0]']
#  Normalization)
#
#  conv2d_231 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_230[0][0]']
#
#  batch_normalization_231 (Batch  (None, 4, 4, 128)   512         ['conv2d_231[0][0]']
#  Normalization)
#
#  add_102 (Add)                  (None, 4, 4, 128)    0           ['batch_normalization_231[0][0]',
#                                                                   'add_101[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 2, 2, 256)    295168      ['add_102[0][0]']
#
#  batch_normalization_232 (Batch  (None, 2, 2, 256)   1024        ['conv2d_232[0][0]']
#  Normalization)
#
#  conv2d_233 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_232[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 2, 2, 256)    295168      ['add_102[0][0]']
#
#  batch_normalization_233 (Batch  (None, 2, 2, 256)   1024        ['conv2d_233[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 2, 2, 256)   1024        ['conv2d_234[0][0]']
#  Normalization)
#
#  add_103 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_233[0][0]',
#                                                                   'batch_normalization_234[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 2, 2, 256)    590080      ['add_103[0][0]']
#
#  batch_normalization_235 (Batch  (None, 2, 2, 256)   1024        ['conv2d_235[0][0]']
#  Normalization)
#
#  conv2d_236 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_235[0][0]']
#
#  batch_normalization_236 (Batch  (None, 2, 2, 256)   1024        ['conv2d_236[0][0]']
#  Normalization)
#
#  add_104 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_236[0][0]',
#                                                                   'add_103[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 2, 2, 256)    590080      ['add_104[0][0]']
#
#  batch_normalization_237 (Batch  (None, 2, 2, 256)   1024        ['conv2d_237[0][0]']
#  Normalization)
#
#  conv2d_238 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_237[0][0]']
#
#  batch_normalization_238 (Batch  (None, 2, 2, 256)   1024        ['conv2d_238[0][0]']
#  Normalization)
#
#  add_105 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_238[0][0]',
#                                                                   'add_104[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 2, 2, 256)    590080      ['add_105[0][0]']
#
#  batch_normalization_239 (Batch  (None, 2, 2, 256)   1024        ['conv2d_239[0][0]']
#  Normalization)
#
#  conv2d_240 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_239[0][0]']
#
#  batch_normalization_240 (Batch  (None, 2, 2, 256)   1024        ['conv2d_240[0][0]']
#  Normalization)
#
#  add_106 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_240[0][0]',
#                                                                   'add_105[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 2, 2, 256)    590080      ['add_106[0][0]']
#
#  batch_normalization_241 (Batch  (None, 2, 2, 256)   1024        ['conv2d_241[0][0]']
#  Normalization)
#
#  conv2d_242 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_241[0][0]']
#
#  batch_normalization_242 (Batch  (None, 2, 2, 256)   1024        ['conv2d_242[0][0]']
#  Normalization)
#
#  add_107 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_242[0][0]',
#                                                                   'add_106[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 2, 2, 256)    590080      ['add_107[0][0]']
#
#  batch_normalization_243 (Batch  (None, 2, 2, 256)   1024        ['conv2d_243[0][0]']
#  Normalization)
#
#  conv2d_244 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_243[0][0]']
#
#  batch_normalization_244 (Batch  (None, 2, 2, 256)   1024        ['conv2d_244[0][0]']
#  Normalization)
#
#  add_108 (Add)                  (None, 2, 2, 256)    0           ['batch_normalization_244[0][0]',
#                                                                   'add_107[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 1, 1, 512)    1180160     ['add_108[0][0]']
#
#  batch_normalization_245 (Batch  (None, 1, 1, 512)   2048        ['conv2d_245[0][0]']
#  Normalization)
#
#  conv2d_246 (Conv2D)            (None, 1, 1, 512)    2359808     ['batch_normalization_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 1, 1, 512)    1180160     ['add_108[0][0]']
#
#  batch_normalization_246 (Batch  (None, 1, 1, 512)   2048        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 1, 1, 512)   2048        ['conv2d_247[0][0]']
#  Normalization)
#
#  add_109 (Add)                  (None, 1, 1, 512)    0           ['batch_normalization_246[0][0]',
#                                                                   'batch_normalization_247[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 1, 1, 512)    2359808     ['add_109[0][0]']
#
#  batch_normalization_248 (Batch  (None, 1, 1, 512)   2048        ['conv2d_248[0][0]']
#  Normalization)
#
#  conv2d_249 (Conv2D)            (None, 1, 1, 512)    2359808     ['batch_normalization_248[0][0]']
#
#  batch_normalization_249 (Batch  (None, 1, 1, 512)   2048        ['conv2d_249[0][0]']
#  Normalization)
#
#  add_110 (Add)                  (None, 1, 1, 512)    0           ['batch_normalization_249[0][0]',
#                                                                   'add_109[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 1, 1, 512)    2359808     ['add_110[0][0]']
#
#  batch_normalization_250 (Batch  (None, 1, 1, 512)   2048        ['conv2d_250[0][0]']
#  Normalization)
#
#  conv2d_251 (Conv2D)            (None, 1, 1, 512)    2359808     ['batch_normalization_250[0][0]']
#
#  batch_normalization_251 (Batch  (None, 1, 1, 512)   2048        ['conv2d_251[0][0]']
#  Normalization)
#
#  add_111 (Add)                  (None, 1, 1, 512)    0           ['batch_normalization_251[0][0]',
#                                                                   'add_110[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 1, 1, 512)   0           ['add_111[0][0]']
#  oling2D)
#
#  flatten_6 (Flatten)            (None, 512)          0           ['average_pooling2d_6[0][0]']
#
#  dense_6 (Dense)                (None, 10)           5130        ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 22,685,322
# Trainable params: 22,668,298
# Non-trainable params: 17,024
# __________________________________________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 84s 39ms/step - loss: 0.2313 - accuracy: 0.9440 - val_loss: 0.3000 - val_accuracy: 0.9224
# Epoch 2/20
# 1875/1875 [==============================] - 74s 39ms/step - loss: 0.0952 - accuracy: 0.9738 - val_loss: 0.1428 - val_accuracy: 0.9628
# Epoch 3/20
# 1875/1875 [==============================] - 72s 39ms/step - loss: 0.0840 - accuracy: 0.9776 - val_loss: 0.9202 - val_accuracy: 0.8468
# Epoch 4/20
# 1875/1875 [==============================] - 74s 40ms/step - loss: 0.0654 - accuracy: 0.9818 - val_loss: 0.0587 - val_accuracy: 0.9788
# Epoch 5/20
# 1875/1875 [==============================] - 72s 39ms/step - loss: 0.0514 - accuracy: 0.9856 - val_loss: 0.2727 - val_accuracy: 0.9310
# Epoch 6/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0689 - accuracy: 0.9831 - val_loss: 0.0950 - val_accuracy: 0.9909
# Epoch 7/20
# 1875/1875 [==============================] - 70s 38ms/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.0314 - val_accuracy: 0.9915
# Epoch 8/20
# 1875/1875 [==============================] - 70s 38ms/step - loss: 0.0468 - accuracy: 0.9886 - val_loss: 0.0348 - val_accuracy: 0.9908
# Epoch 9/20
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.0293 - accuracy: 0.9922 - val_loss: 0.2333 - val_accuracy: 0.9425
# Epoch 10/20
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.0299 - accuracy: 0.9923 - val_loss: 0.0248 - val_accuracy: 0.9932
# Epoch 11/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0279 - accuracy: 0.9930 - val_loss: 0.0494 - val_accuracy: 0.9863
# Epoch 12/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0211 - accuracy: 0.9944 - val_loss: 0.0366 - val_accuracy: 0.9901
# Epoch 13/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0295 - val_accuracy: 0.9912
# Epoch 14/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0466 - val_accuracy: 0.9917
# Epoch 15/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 20.5363 - val_accuracy: 0.9902
# Epoch 16/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 1338853.7500 - val_accuracy: 0.9897
# Epoch 17/20
# 1875/1875 [==============================] - 73s 39ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 2.2890 - val_accuracy: 0.9893
# Epoch 18/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 34456956.0000 - val_accuracy: 0.9849
# Epoch 19/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 83.2131 - val_accuracy: 0.9885
# Epoch 20/20
# 1875/1875 [==============================] - 71s 38ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0227 - val_accuracy: 0.9941
#
# Test accuracy: 99.4%

# %%
# Out:
# TensorShape([60000, 34, 34, 1])
